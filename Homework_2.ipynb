# %%
#import dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("diamonds.csv")

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# ...

# %%
pd.crosstab(df.cut,df.color)
# Out:
# color         D     E     F     G     H     I    J
# cut
# Fair        163   224   312   314   303   175  119
# Good        662   933   909   871   702   522  307
# Ideal      2834  3903  3826  4884  3115  2093  896
# Premium    1603  2337  2331  2924  2360  1428  808
# Very Good  1513  2400  2164  2299  1824  1204  678

# %%
df.color.value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
pd.crosstab(df.cut,df.color).plot(kind='bar')

# %%
df.color.value_counts().plot(kind='pie')

# %%
import seaborn as sns

# %%
sns.boxplot(x='carat',y='price',data=df)

# %%
sns.pairplot(df.iloc[:,:])

# %%
plt.scatter(df.carat,df.price)

# %%
plt.hist(df['price'])
# Out:
# (array([25335.,  9328.,  7393.,  3878.,  2364.,  1745.,  1306.,  1002.,
#           863.,   726.]),
#  array([  326. ,  2175.7,  4025.4,  5875.1,  7724.8,  9574.5, 11424.2,
#         13273.9, 15123.6, 16973.3, 18823. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df['price'],facecolor='black',edgecolor='red',bins=5)
# Out:
# (array([34663., 11271.,  4109.,  2308.,  1589.]),
#  array([  326. ,  4025.4,  7724.8, 11424.2, 15123.6, 18823. ]),
#  <a list of 5 Patch objects>)

# %%
plt.boxplot(df.price,vert='True')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bee2d4e4c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2bee2d4ed88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2bee2d48b08>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bee2d53d08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bee2d58b88>],
#  'means': []}

# %%
plt.violinplot(df.price)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2bee2db2a08>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2bee2d74ac8>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2bee2dbba48>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2bee2dbb9c8>}

# %%
sns.set_style("darkgrid", {'axes.grid' : True})
sns.lmplot(x= 'carat', y='price', data=df)
plt.show()

# %%
sns.lmplot(x='carat', y='price', data=df, hue='clarity',palette='Set2')
plt.show()

# %%
sns.lmplot(x='carat', y='price', data=df, col='clarity')
plt.show()
